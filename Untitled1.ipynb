# %% [markdown]
# <a href="https://colab.research.google.com/github/davegauravgithub/My-AIML-Projects/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
df = pd.read_excel('data.xlsx')
df
# Out:
#      Computer Time  Time (Milli Sec.)  AmmeterS1  VoltmeterS2  PressureS3  \
# 0         14:56:05             1262.0   2.465394     201.3889     6734.81
# 1         14:56:07             2513.0   2.465394     201.3889     4209.26
# 2         14:56:08             3765.0   2.444734     203.7037     5051.11
# 3         14:56:09             5016.0   2.460474     203.1250     5051.11
# 4         14:56:10             6267.0   2.445718     201.3889     5051.11
# ...            ...                ...        ...          ...         ...
# 998       15:16:56          1250556.0   2.463426     240.4514         NaN
# 999       15:16:58          1251809.0   2.445718     239.8727         NaN
# 1000      15:16:59          1253060.0   2.455556     240.7407         NaN
# 1001           NaN                NaN   2.453588     241.3194         NaN
# 1002           NaN                NaN   2.449653          NaN         NaN
#
#       FlowMeterS4  AvgAccS5  AvgAccS6  AvgAccs7  AvgAccS8
# ...

# %%
x = df['Time (Milli Sec.)']
y = df['AmmeterS1']
plt.plot(x,y)
plt.show()

# %%
x = df['Time (Milli Sec.)']
y = df['VoltmeterS2']
plt.plot(x,y)
plt.show()

# %%
x = df['Time (Milli Sec.)']
y = df['FlowMeterS4']
plt.plot(x,y)
plt.show()

# %%
x = df['Time (Milli Sec.)']
y = df['PressureS3']
plt.plot(x,y)
plt.show()

# %%
x = df['Time (Milli Sec.)']
y = df['AvgAccS5']
plt.plot(x,y)
plt.show()

# %%
x = df['Time (Milli Sec.)']
y = df['AvgAccS6']
plt.plot(x,y)
plt.show()

# %%
x = df['Time (Milli Sec.)']
y = df['AvgAccs7']
plt.plot(x,y)
plt.show()
